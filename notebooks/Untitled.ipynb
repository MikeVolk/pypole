# %%
import sys
from pathlib import Path

sys.path.append(str(Path.cwd().parents[1]))

# %%
# %load_ext autoreload
# %autoreload 2
# %config InlineBackend.figure_format = 'retina'
# %config Completer.use_jedi = False
# %matplotlib inline

# %%
import pypole
import numpy as np
import matplotlib.pyplot as plt

# %%
from pypole import dipole, maps, fit

# %%
np.random.seed(0)

# %%
d = dipole.synthetic_map()

# %%
plt.imshow(d)

# %%
fit.fit_dipole(b_map=d, p0=[0,0,0

# %%
np.random.seed(0)

# %%
x, y = maps.get_grid(pixel_size=5e-7, n_pixel=100)
location, vec = maps.get_random_sources(100)

# %%
d1 = dipole.calculate_map(x,y,location, vec)

# %%
plt.imshow(d1)
